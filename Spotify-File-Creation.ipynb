# %% [markdown]
# # Creating the Spotify Data File
# Creation of three Pandas DataFrames:
#  - Tracks
#  - Audio Features
#  - Final merged table
#
# **POTENTIAL ACTIONS**
#  - It may be worth cleaning the final DataFrame a bit, removing unwanted columns
#  - Do we want to try & add some more info for analysis? (e.g. Can album info be extracted?)

# %%
# Import relevant libraries & Spotify Credentials
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotify_creds import cid
from spotify_creds import secret
import pandas as pd

# Load up Spotify credentials
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Loop for creating the track information
artist_name = []
track_name = []
popularity = []
track_id = []
album_id = []
release_date = []
markets = []
album_name = []
followers = []
genres = []

track_results = sp.playlist("46UsmalBN8doF25XHQuUpZ")
for i, t in enumerate(track_results['tracks']["items"]):
    artist_name.append(t["track"]["artists"][0]["name"])
    track_name.append(t["track"]["name"])
    track_id.append(t["track"]["id"])
    popularity.append(t["track"]["popularity"])
    album_id.append(t["track"]["album"]["id"])
    genres.append(sp.artist(t["track"]["artists"][0]["id"])["genres"])
    release_date.append(t["track"]["album"]["release_date"])
    markets.append(t["track"]["album"]["available_markets"])
    album_name.append(t["track"]["album"]["name"])
    followers.append(sp.artist(t["track"]["artists"][0]["id"])["followers"]["total"])

# %%
# Read .csv containing number of streams

stream_df = pd.read_csv("stream-counts.csv")
num_streams = stream_df["Streams"].tolist()

# %%
charts_df = pd.DataFrame({"artist_name" : artist_name,
                         "artist_genres" : genres,
                         "album_id" : album_id,
                         "album_name" : album_name,
                         'track_id' : track_id,
                         'track_name' : track_name,
                         "streams (millions)" : num_streams,
                         'popularity' : popularity,
                         "release_date" : release_date,
                         "markets" : markets,
                         "followers" : followers})
charts_df
# Out:
#       artist_name                                      artist_genres  \
# 0      Ed Sheeran                                      [pop, uk pop]
# 1      The Weeknd     [canadian contemporary r&b, canadian pop, pop]
# 2     Tones And I                              [australian pop, pop]
# 3     Post Malone                        [dfw rap, melodic rap, rap]
# 4   Lewis Capaldi                                      [pop, uk pop]
# ..            ...                                                ...
# 95   benny blanco                         [electropop, pop, pop rap]
# 96   Charlie Puth                        [dance pop, pop, viral pop]
# 97    Major Lazer  [dance pop, edm, electro house, moombahton, po...
# 98            OMI                                        [dance pop]
# 99     The Weeknd     [canadian contemporary r&b, canadian pop, pop]
#
#                   album_id                                   album_name  \
# 0   3T4tUhGYeRNVUGevb0wThu                                   ÷ (Deluxe)
# 1   4yP0hdKOZPNshxUOjY0cZj                                  After Hours
# 2   0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
# 3   6trNtQUgC8cgbWcqoMYkOR                         beerbongs & bentleys
# 4   5658aM19fA3JVwTK6eQX70      Divinely Uninspired To A Hellish Extent
# ..                     ...                                          ...
# 95  7pkLXlFdpQDfmHujT2AbBK              Eastside (with Halsey & Khalid)
# 96  6E0p38TjcK490itZ1Ns7bD                              Nine Track Mind
# 97  4SpuU8HT32EymGgFPL08LE        Cold Water (feat. Justin Bieber & MØ)
# 98  7cVXH4slEYzGjDh498OFyL                                       Me 4 U
# 99  0P3oVJBFOv3TDXlYRhGL7s                    Beauty Behind The Madness
#
#                   track_id                                  track_name  \
# 0   7qiZfU4dY1lWllzX7mPBI3                                Shape of You
# 1   0VjIjW4GlUZAMYd2vXMi3b                             Blinding Lights
# 2   2XU0oxnq2qxCpomAAuJY8K                                Dance Monkey
# 3   0e7ipj03S05BNilyu5bRzt                  rockstar (feat. 21 Savage)
# 4   7qEHsqek33rTcFNT9PFqLf                           Someone You Loved
# ..                     ...                                         ...
# 95  0d2iYfpKoM0QCKvcLCkBao             Eastside (with Halsey & Khalid)
# 96  68EMU2RD1ECNeOeJ5qAXCV  We Don't Talk Anymore (feat. Selena Gomez)
# 97  6Bjtr3tPdto5nyuLYf61sN       Cold Water (feat. Justin Bieber & MØ)
# 98  7vFoFDWqTX0mHzLfrF1Cfy  Cheerleader - Felix Jaehn Remix Radio Edit
# 99  22VdIZQfgXJea34mQxlt81                          Can't Feel My Face
#
#    streams (millions)  popularity release_date  \
# 0               2,989          87   2017-03-03
# 1               2,673          93   2020-03-20
# 2               2,425          82   2019-10-17
# 3               2,312          85   2018-04-27
# 4               2,182          88   2019-05-17
# ..                ...         ...          ...
# 95              1,247          79   2018-07-12
# 96              1,243          59   2015-11-05
# 97              1,238          72   2016-07-22
# 98              1,235          78   2015-10-16
# 99              1,229          81   2015-08-28
#
#                                               markets  followers
# 0   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...   88961926
# 1   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...   39308599
# 2   [AD, AE, AG, AL, AM, AO, AR, AT, AZ, BA, BB, B...    2888374
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...   35093420
# 4   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...    8940823
# ..                                                ...        ...
# 95  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...     849006
# 96                                               [GB]   14626796
# 97  [AD, AE, AL, AO, AR, AT, AZ, BA, BE, BF, BG, B...    6250081
# 98  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...     584717
# 99  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...   39308599
#
# [100 rows x 11 columns]

# %%
# Create the list of track features
features = []

for x in track_id:
    features.append(sp.audio_features(x))

# %%
# Create the DataFrame for track features
feat_df = pd.DataFrame()

for i in range(100):
    feat_df = feat_df.append(features[i][0],ignore_index=True)
    
# Rename track id column for future merging with the other DataFrame
feat_df.rename(columns = {'id':'track_id'}, inplace = True)
feat_df
# Out:
#     acousticness                                       analysis_url  \
# 0        0.58100  https://api.spotify.com/v1/audio-analysis/7qiZ...
# 1        0.00146  https://api.spotify.com/v1/audio-analysis/0VjI...
# 2        0.69200  https://api.spotify.com/v1/audio-analysis/2XU0...
# 3        0.12400  https://api.spotify.com/v1/audio-analysis/0e7i...
# 4        0.75100  https://api.spotify.com/v1/audio-analysis/7qEH...
# ..           ...                                                ...
# 95       0.55500  https://api.spotify.com/v1/audio-analysis/0d2i...
# 96       0.62100  https://api.spotify.com/v1/audio-analysis/68EM...
# 97       0.07360  https://api.spotify.com/v1/audio-analysis/6Bjt...
# 98       0.16600  https://api.spotify.com/v1/audio-analysis/7vFo...
# 99       0.11300  https://api.spotify.com/v1/audio-analysis/22Vd...
#
#     danceability  duration_ms  energy                track_id  \
# 0          0.825     233713.0   0.652  7qiZfU4dY1lWllzX7mPBI3
# 1          0.514     200040.0   0.730  0VjIjW4GlUZAMYd2vXMi3b
# 2          0.824     209438.0   0.588  2XU0oxnq2qxCpomAAuJY8K
# 3          0.585     218147.0   0.520  0e7ipj03S05BNilyu5bRzt
# 4          0.501     182161.0   0.405  7qEHsqek33rTcFNT9PFqLf
# ..           ...          ...     ...                     ...
# 95         0.560     173800.0   0.680  0d2iYfpKoM0QCKvcLCkBao
# 96         0.728     217707.0   0.563  68EMU2RD1ECNeOeJ5qAXCV
# 97         0.608     185352.0   0.798  6Bjtr3tPdto5nyuLYf61sN
# 98         0.782     180566.0   0.685  7vFoFDWqTX0mHzLfrF1Cfy
# 99         0.705     213520.0   0.769  22VdIZQfgXJea34mQxlt81
#
#     instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0           0.000000  1.0    0.0931    -3.183   0.0       0.0802   95.977
# 1           0.000095  1.0    0.0897    -5.934   1.0       0.0598  171.005
# 2           0.000104  6.0    0.1490    -6.400   0.0       0.0924   98.027
# 3           0.000070  5.0    0.1310    -6.136   0.0       0.0712  159.801
# 4           0.000000  1.0    0.1050    -5.679   1.0       0.0319  109.891
# ..               ...  ...       ...       ...   ...          ...      ...
# 95          0.000000  6.0    0.1160    -7.648   0.0       0.3210   89.391
# 96          0.000000  1.0    0.1790    -8.053   0.0       0.1340  100.017
# 97          0.000000  6.0    0.1560    -5.092   0.0       0.0432   92.943
# 98          0.000012  4.0    0.1600    -6.237   1.0       0.0309  118.016
# 99          0.000000  9.0    0.1050    -5.526   0.0       0.0425  107.949
#
#     time_signature                                         track_href  \
# 0              4.0  https://api.spotify.com/v1/tracks/7qiZfU4dY1lW...
# 1              4.0  https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
# 2              4.0  https://api.spotify.com/v1/tracks/2XU0oxnq2qxC...
# 3              4.0  https://api.spotify.com/v1/tracks/0e7ipj03S05B...
# 4              4.0  https://api.spotify.com/v1/tracks/7qEHsqek33rT...
# ..             ...                                                ...
# 95             4.0  https://api.spotify.com/v1/tracks/0d2iYfpKoM0Q...
# 96             4.0  https://api.spotify.com/v1/tracks/68EMU2RD1ECN...
# 97             4.0  https://api.spotify.com/v1/tracks/6Bjtr3tPdto5...
# 98             4.0  https://api.spotify.com/v1/tracks/7vFoFDWqTX0m...
# 99             4.0  https://api.spotify.com/v1/tracks/22VdIZQfgXJe...
#
#               type                                   uri  valence
# 0   audio_features  spotify:track:7qiZfU4dY1lWllzX7mPBI3    0.931
# 1   audio_features  spotify:track:0VjIjW4GlUZAMYd2vXMi3b    0.334
# 2   audio_features  spotify:track:2XU0oxnq2qxCpomAAuJY8K    0.513
# 3   audio_features  spotify:track:0e7ipj03S05BNilyu5bRzt    0.129
# 4   audio_features  spotify:track:7qEHsqek33rTcFNT9PFqLf    0.446
# ..             ...                                   ...      ...
# 95  audio_features  spotify:track:0d2iYfpKoM0QCKvcLCkBao    0.319
# 96  audio_features  spotify:track:68EMU2RD1ECNeOeJ5qAXCV    0.352
# 97  audio_features  spotify:track:6Bjtr3tPdto5nyuLYf61sN    0.501
# 98  audio_features  spotify:track:7vFoFDWqTX0mHzLfrF1Cfy    0.603
# 99  audio_features  spotify:track:22VdIZQfgXJea34mQxlt81    0.583
#
# [100 rows x 18 columns]

# %%
# Merge the two DataFrames together & remove any duplicate tracks to get final data file
spotify_df = charts_df.merge(feat_df, how = "outer", on = "track_id")
spotify_df
# Out:
#       artist_name                                      artist_genres  \
# 0      Ed Sheeran                                      [pop, uk pop]
# 1      The Weeknd     [canadian contemporary r&b, canadian pop, pop]
# 2     Tones And I                              [australian pop, pop]
# 3     Post Malone                        [dfw rap, melodic rap, rap]
# 4   Lewis Capaldi                                      [pop, uk pop]
# ..            ...                                                ...
# 95   benny blanco                         [electropop, pop, pop rap]
# 96   Charlie Puth                        [dance pop, pop, viral pop]
# 97    Major Lazer  [dance pop, edm, electro house, moombahton, po...
# 98            OMI                                        [dance pop]
# 99     The Weeknd     [canadian contemporary r&b, canadian pop, pop]
#
#                   album_id                                   album_name  \
# 0   3T4tUhGYeRNVUGevb0wThu                                   ÷ (Deluxe)
# 1   4yP0hdKOZPNshxUOjY0cZj                                  After Hours
# 2   0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
# 3   6trNtQUgC8cgbWcqoMYkOR                         beerbongs & bentleys
# 4   5658aM19fA3JVwTK6eQX70      Divinely Uninspired To A Hellish Extent
# ..                     ...                                          ...
# 95  7pkLXlFdpQDfmHujT2AbBK              Eastside (with Halsey & Khalid)
# 96  6E0p38TjcK490itZ1Ns7bD                              Nine Track Mind
# 97  4SpuU8HT32EymGgFPL08LE        Cold Water (feat. Justin Bieber & MØ)
# 98  7cVXH4slEYzGjDh498OFyL                                       Me 4 U
# 99  0P3oVJBFOv3TDXlYRhGL7s                    Beauty Behind The Madness
#
#                   track_id                                  track_name  \
# 0   7qiZfU4dY1lWllzX7mPBI3                                Shape of You
# 1   0VjIjW4GlUZAMYd2vXMi3b                             Blinding Lights
# 2   2XU0oxnq2qxCpomAAuJY8K                                Dance Monkey
# 3   0e7ipj03S05BNilyu5bRzt                  rockstar (feat. 21 Savage)
# 4   7qEHsqek33rTcFNT9PFqLf                           Someone You Loved
# ..                     ...                                         ...
# 95  0d2iYfpKoM0QCKvcLCkBao             Eastside (with Halsey & Khalid)
# 96  68EMU2RD1ECNeOeJ5qAXCV  We Don't Talk Anymore (feat. Selena Gomez)
# 97  6Bjtr3tPdto5nyuLYf61sN       Cold Water (feat. Justin Bieber & MØ)
# 98  7vFoFDWqTX0mHzLfrF1Cfy  Cheerleader - Felix Jaehn Remix Radio Edit
# 99  22VdIZQfgXJea34mQxlt81                          Can't Feel My Face
#
#    streams (millions)  popularity release_date  \
# 0               2,989          87   2017-03-03
# 1               2,673          93   2020-03-20
# 2               2,425          82   2019-10-17
# 3               2,312          85   2018-04-27
# 4               2,182          88   2019-05-17
# ..                ...         ...          ...
# 95              1,247          79   2018-07-12
# 96              1,243          59   2015-11-05
# 97              1,238          72   2016-07-22
# 98              1,235          78   2015-10-16
# 99              1,229          81   2015-08-28
#
#                                               markets  ...  liveness  \
# 0   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...  ...    0.0931
# 1   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...  ...    0.0897
# 2   [AD, AE, AG, AL, AM, AO, AR, AT, AZ, BA, BB, B...  ...    0.1490
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...  ...    0.1310
# 4   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...  ...    0.1050
# ..                                                ...  ...       ...
# 95  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...  ...    0.1160
# 96                                               [GB]  ...    0.1790
# 97  [AD, AE, AL, AO, AR, AT, AZ, BA, BE, BF, BG, B...  ...    0.1560
# 98  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...  ...    0.1600
# 99  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...  ...    0.1050
#
#     loudness mode  speechiness    tempo  time_signature  \
# 0     -3.183  0.0       0.0802   95.977             4.0
# 1     -5.934  1.0       0.0598  171.005             4.0
# 2     -6.400  0.0       0.0924   98.027             4.0
# 3     -6.136  0.0       0.0712  159.801             4.0
# 4     -5.679  1.0       0.0319  109.891             4.0
# ..       ...  ...          ...      ...             ...
# 95    -7.648  0.0       0.3210   89.391             4.0
# 96    -8.053  0.0       0.1340  100.017             4.0
# 97    -5.092  0.0       0.0432   92.943             4.0
# 98    -6.237  1.0       0.0309  118.016             4.0
# 99    -5.526  0.0       0.0425  107.949             4.0
#
#                                            track_href            type  \
# 0   https://api.spotify.com/v1/tracks/7qiZfU4dY1lW...  audio_features
# 1   https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...  audio_features
# 2   https://api.spotify.com/v1/tracks/2XU0oxnq2qxC...  audio_features
# 3   https://api.spotify.com/v1/tracks/0e7ipj03S05B...  audio_features
# 4   https://api.spotify.com/v1/tracks/7qEHsqek33rT...  audio_features
# ..                                                ...             ...
# 95  https://api.spotify.com/v1/tracks/0d2iYfpKoM0Q...  audio_features
# 96  https://api.spotify.com/v1/tracks/68EMU2RD1ECN...  audio_features
# 97  https://api.spotify.com/v1/tracks/6Bjtr3tPdto5...  audio_features
# 98  https://api.spotify.com/v1/tracks/7vFoFDWqTX0m...  audio_features
# 99  https://api.spotify.com/v1/tracks/22VdIZQfgXJe...  audio_features
#
#                                      uri  valence
# 0   spotify:track:7qiZfU4dY1lWllzX7mPBI3    0.931
# 1   spotify:track:0VjIjW4GlUZAMYd2vXMi3b    0.334
# 2   spotify:track:2XU0oxnq2qxCpomAAuJY8K    0.513
# 3   spotify:track:0e7ipj03S05BNilyu5bRzt    0.129
# 4   spotify:track:7qEHsqek33rTcFNT9PFqLf    0.446
# ..                                   ...      ...
# 95  spotify:track:0d2iYfpKoM0QCKvcLCkBao    0.319
# 96  spotify:track:68EMU2RD1ECNeOeJ5qAXCV    0.352
# 97  spotify:track:6Bjtr3tPdto5nyuLYf61sN    0.501
# 98  spotify:track:7vFoFDWqTX0mHzLfrF1Cfy    0.603
# 99  spotify:track:22VdIZQfgXJea34mQxlt81    0.583
#
# [100 rows x 28 columns]

# %%
# Export files to .csv (optional)

spotify_df.to_csv("spotify-data.csv", index = False)
feat_df.to_csv("features.csv", index = False)
charts_df.to_csv("tracks.csv", index = False)
